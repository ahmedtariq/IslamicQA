# %%
# 1. Imports and Setup
import os
import pandas as pd
import json

# %%
# Load Ayatec QA pairs
ayatec = pd.read_csv("../Data/preprocessed_questions_with_answers_train.csv")  # ensure columns: question, surah_number, ayah_start, ayah_end

# Load Ayatec QA pairs
ayatec_dev = pd.read_csv("../Data/preprocessed_questions_with_answers_dev.csv")  # ensure columns: question, surah_number, ayah_start, ayah_end

ayatec_test = pd.read_csv("../Data/preprocessed_questions_test.csv")  # ensure columns: question

# %% [markdown]
# # Task
# Enrich Arabic questions in the dataset with possible answers and vocabulary synonyms using an LLM.

# %% [markdown]
# ## Identify arabic questions
#
# ### Subtask:
# Extract the unique Arabic questions from the dataset.

# %% [markdown]
# **Reasoning**:
# Extract the unique Arabic questions from the `ayatec` DataFrame and store them in a list.

# %%
unique_arabic_questions = ayatec['arabic'].unique().tolist()
unique_arabic_questions_dev = ayatec_dev['arabic'].unique().tolist()
unique_arabic_questions_test = ayatec_test['arabic'].unique().tolist()
print(f"Number of unique Arabic questions: {len(unique_arabic_questions)}")
print(f"Number of unique Arabic questions in dev set: {len(unique_arabic_questions_dev)}")
print(f"Number of unique Arabic questions in test set: {len(unique_arabic_questions_test)}")
print("First 10 unique Arabic questions:")
for q in unique_arabic_questions[:10]:
    print(q)
# Out:
# Number of unique Arabic questions: 210
# Number of unique Arabic questions in dev set: 40
# Number of unique Arabic questions in test set: 53
# First 10 unique Arabic questions:
# من هم قوم شعيب؟
# من هم قوم موسى؟
# من بنى الكعبة؟
# من هو النبي المعروف بالصبر؟
# من كفل السيدة مريم؟
# ما معنى الحطمة؟
# من هو اخو سيدنا موسى؟
# ما معنى القارعة؟
# ما معنى الجاثية؟
# من هم الاسباط؟

# %% [markdown]
# ## Prepare llm prompts
#
# ### Subtask:
# Create prompts for the LLM, asking it to provide possible answers and vocabulary synonyms for each Arabic question.

# %% [markdown]
# **Reasoning**:
# Define a function to create the LLM prompt for Arabic questions, asking for possible answers and vocabulary synonyms in a structured format.

# %%
def create_llm_prompt(arabic_question):
    """
    Creates an LLM prompt in Arabic to get possible answers and vocabulary synonyms
    for a given Arabic question.

    Args:
        arabic_question (str): The Arabic question.

    Returns:
        str: The constructed LLM prompt in Arabic.
    """
    prompt = f"""
    أعطني إجابة باقل من ١٠ كلمات باستخدام مصطلحات من القرآن و الحديث و اللغة العربية الفصحى.
    ...

    السؤال: {arabic_question}
    """
    return prompt.strip()

# %% [markdown]
# ## Call llm
#
# ### Subtask:
# Iterate through the questions and call an LLM (e.g., using the `google.generativeai` library if available and configured) with the prepared prompts.

# %% [markdown]
# **Reasoning**:
# Initialize the LLM model and iterate through the unique Arabic questions to get responses.

# %%
# Import necessary libraries
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from huggingface_hub import notebook_login
# Out:
# /Users/ahmed/Documents/Academic/Competitions/IslamicEval - Online/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Authenticate with Hugging Face Hub (if needed for the model)
# You might need to run this cell separately and log in
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Load the Jais model and tokenizer
# You might need to specify the exact model name if "Jais" is ambiguous (e.g., "core42/jais-13b-chat")
model_name = "core42/jais-13b-chat" # Example model name, please verify the correct one
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        torch_dtype=torch.bfloat16, # Use bfloat16 for potentially lower memory usage
        trust_remote_code=True,
        # Add quantization for memory efficiency if needed
        # load_in_4bit=True,
        # bnb_4bit_compute_dtype=torch.bfloat16,
    )
    # Move model to MPS if available
    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    model = model.to(device)
    print(f"Successfully loaded model '{model_name}'.")

except Exception as e:
    print(f"Failed to load model '{model_name}': {e}")
    # If model loading fails, we cannot proceed
    raise
# Out:
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Successfully loaded model 'core42/jais-13b-chat'.

# %%
def get_llm_responces(unique_arabic_questions):
    # Dictionary to store LLM responses
    llm_responses = {}

    # Iterate through unique Arabic questions and get model responses
    print(f"Processing {len(unique_arabic_questions)} unique Arabic questions...")
    for i, question in enumerate(unique_arabic_questions[:]):
        prompt = create_llm_prompt(question) # Reuse the existing prompt function

        try:
            # Prepare input for the model
            inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

            # Generate response
            # You might need to adjust generation parameters like max_length, num_beams, etc.
            with torch.no_grad():
                outputs = model.generate(**inputs, max_length=512, num_return_sequences=1)

            # Decode the response
            response_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

            # Store the text response
            llm_responses[question] = response_text

            if (i + 1) % 10 == 0:
                print(f"Processed {i + 1}/{len(unique_arabic_questions)} questions.")

        except Exception as e:
            print(f"Error processing question '{question}': {e}")
            # Store an informative error message for failed requests
            llm_responses[question] = f"Error: {e}"

    # Print summary
    successful_responses = sum(1 for resp in llm_responses.values() if not str(resp).startswith("Error:"))
    print(f"\nSuccessfully received responses for {successful_responses}/{len(unique_arabic_questions)} questions.")
    failed_responses = len(unique_arabic_questions) - successful_responses
    print(f"Failed to receive responses for {failed_responses}/{len(unique_arabic_questions)} questions.")

    # Display a sample successful response
    if successful_responses > 0:
        print("\nSample LLM Response:")
        # Find the first question with a successful response
        sample_question = None
        for q, resp in llm_responses.items():
            if not str(resp).startswith("Error:"):
                sample_question = q
                break
        if sample_question:
            print(f"Question: {sample_question}")
            print("Response:")
            print(llm_responses[sample_question])
        else:
            print("No successful responses found to display.")
    else:
        print("No successful responses received.")
    return llm_responses

# %%
unique_arabic_questions_test
# Out:
# [nan,
#  'هل يعتبر الاعتراف بالذنب من الأعمال الصالحة؟',
#  ' كم عدد الكواكب في الكون؟',
#  'ما هي وسائل التكفيرعن الذنوب والمعاصي؟',
#  'ما الفلاح الحقيقي في الآخرة؟',
#  'في أي بلد يقع مقام سيدنا إبراهيم عليه السلام؟',
#  'ما هي طرق تطهير القلب وتحليته بالصفات المحمودة؟',
#  'ماذا يشمل العدوان في النصوص الشرعية؟',
#  'هل يجوز التكسّب برسم ما لا روح فيه؟',
#  'أين تذهب أرواح المؤمنين الذين استشهدوا لحين يوم القيامة؟',
#  'ما حكم زرع الأعضاء البشرية بين الأحياء؟',
#  'ما عمر الأرض بالسنوات تحديدًا؟',
#  'لماذا كان الرسول (صلى الله عليه وسلم) يُكثر من الاستغفار مع علمه بأن الله قد غفر له ما تقدم وما تأخر من ذنوبه؟',
#  'ما الأعمال التي تساعد في جلب الرزق؟',
#  'متى تكون مجرما بحق نفسك؟',
#  'ما الدليل على أن كون الإنسان مسلمًا لا يعني بالضرورة أنه بلغ مرتبة الإيمان؟',
#  'ما حكم العلاقة الجنسية خارج إطار الزواج في الإسلام؟',
#  'ما ضوابط وآداب الحرب في الإسلام؟',
#  'ما الغاية من الصيام؟',
#  'ما هو موقف الإسلام من الموت الرحيم (الموت بمساعدة طبية)؟',
#  'يختلف القرين الذي يصاحب المؤمن عن الذي يصاحب الكافر فما الدليل؟',
#  'هل يُعد من نعم الله على العبد أن يوفقه للدعاء؟',
#  'ما موقف الإسلام من إهدار وقت كبير في المباحات التي لا تعود بنفع أو ضرر؟',
#  'كيف تعامل النبي محمد صلى الله عليه وسلم مع الأطفال؟',
#  'كيف يُبعث المرابي يوم القيامة؟',
#  'ما الأعمال التي قد تحجب الرزق؟',
#  'ما هي الصفات السلبية لطبيعة النفس الإنسانية؟',
#  'هل في القرآن أو السنة النبوية  ما يمنع التواجد في أماكن يُشرب فيها الخمر؟',
#  'ما الفلاح الحقيقي في الدنيا؟',
#  'هل الإسلام والإيمان مفهوم واحد؟',
#  ' لماذا يُبتلى بعض الأطفال بالأمراض وهم بلا ذنب؟',
#  'ما الحكمة في خلق إبليس بدلًا من أن يكون جميع الخلق طائعين بلا اختيار؟',
#  'هل أكل لحم الجمل محلّل في الإسلام؟',
#  'كيف يمكن التعريف بشخصية الرسول صلى الله عليه وسلم وصفاته الحميدة؟',
#  'ما الحكم الشرعي للإجهاض بعد نفخ الروح في الجنين؟',
#  'ماذا تعني العبودية لغير الله؟',
#  'ما حكم التصوير بالأشعة فوق البنفسجية لأغراض الكشف الطبي؟',
#  'ما المواضع والأسباب التي ورد فيها التحذير من الغفلة في القرآن الكريم والسنة النبوية؟',
#  'ما أنواع الصبر في الإسلام؟',
#  'ما حكم التحول الجنسي (تغيير الجنس) في الإسلام عندما يكون الدافع إليه مجرد الرغبة الشخصية أو تحقيق الرفاهية؟',
#  'ما الأدلة على أن الرسول صلى الله عليه وسلم عمل بمبدأ الشورى؟',
#  'ماذا تعني العبودية لله؟',
#  'ما الحكمة في عدد ركعات كل صلاة بالتحديد؟',
#  ' ما الحكمة في إخفاء ليلة القدر في العشر الأواخر من رمضان وعدم التصريح بها بشكل قاطع؟',
#  'ما هو حكم زواج المرأة المسلمة من رجل مسيحي؟',
#  'هل يُعتبر الحوار مع أتباع الديانات الأخرى واجبًا على المسلم في سياق الدعوة إلى الإسلام؟',
#  'ما هو الإتقان؟',
#  ' ما العوامل التي تُحبط العمل الصالح وتحول دون قبوله في الآخرة؟',
#  'كم مرة يُعاقب المنافق في الدنيا؟',
#  'ما الدليل على أن الشك وسيلة لصناعة اليقين والمعرفة؟',
#  'ما النصوص الشرعية التي تتحدث عن ظاهرة التقاء الماء العذب بالماء المالح دون اختلاطهما؟',
#  'كيف يرتبط إخلاص العمل لله مع ثواب وأجر ذلك العمل في الآخرة؟',
#  'هل ذُكر التصفيق في القرآن أو السنة النبوية؟']

# %%
llm_responces_test
# Out:
# {nan: 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: nanette, 5,000,000\n    الإجابة: "إن الله على كل شيء قدير".',
#  'هل يعتبر الاعتراف بالذنب من الأعمال الصالحة؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: هل يعتبر الاعتراف بالذنب من الأعمال الصالحة؟\n    ب) الاعتراف بالذنب ليس عملا صالحا ، بل هو من الأعمال السيئة.\n    ج) الاعتراف بالذنب ليس عملا صالحا ، بل هو من الأعمال الحسنة.\n    د) الاعتراف بالذنب ليس عملا سيئا ولا عملا صالحا.\n    ه) الاعتراف بالذنب هو عمل صالح وسيء على حد سواء.\n    """\n    أ) صحيح\n    ب) كاذبة\n    ج) جيد\n    د) سيئة\n    E) كلاهما\n    F) ولا\n    G) ولا واحد\n    H) واحد أو آخر\n    J) إما / أو\n    K) واحد\n    L) اثنين\n    M) ثلاثة\n    N) أربعة\n    O) خمسة\n    P) ستة\n    س) سبعة\n    R) ثمانية\n    S) تسعة\n    T) عشرة\n    U) أحد عشر\n    V) اثنا عشر\n    W) ثلاثة عشر\n    X) أربعة عشر\n    Y) خمسة عشر\n    Z) ستة عشر\n    "0"\n    أ) صحيح\n    ب) كاذبة\n    ج) جيد\n    د) سيئة\n    E) كلاهما\n    F) ولا\n    G) ولا واحد\n    H) واحد أو آخر\n    J) إما / أو\n    K) واحد\n    L) اثنين\n    M) ثلاثة\n    N) أربعة\n    O) خمسة\n    P) ستة\n    س) سبعة\n    R) ثمانية\n    S) تسعة\n    T) عشرة\n    U) أحد عشر\n    V) اثنا عشر\n    W) ثلاثة عشر\n    X) أربعة عشر\n    Y) خمسة عشر\n    Z) ستة عشر\n    "0"\n    أ) صحيح\n    ب) كاذبة\n    ج) جيد\n    د) سيئة\n    E) كلاهما\n    F) ولا\n    G) ولا واحد\n    H) واحد أو آخر\n    J) إما / أو\n    K) واحد\n    L) اثنين\n    M) ثلاثة\n    N) أربعة\n    O) خمسة\n    P) ستة\n    س) سبعة\n    R) ثمانية\n    S) تسعة\n    T) عشرة\n    U) أحد عشر\n    V) اثنا عشر\n    W) ثلاثة عشر\n    X) أربعة عشر\n    Y) خمسة عشر\n    Z) ستة عشر\n    "0"\n    أ) صحيح\n    ب) كاذبة\n    ج) جيد\n    د) سيئة\n    E) كلاهما\n    F) ولا\n    G) ولا واحد\n    H) واحد أو آخر\n    J) إما / أو\n    K) واحد\n    L) اثنين\n    M) ثلاثة\n    N) أربعة\n    O) خمسة\n    P) ستة\n    س) سبعة\n    R) ثمانية\n    S) تسعة\n    T',
#  ' كم عدد الكواكب في الكون؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال:  كم عدد الكواكب في الكون؟\n    الجواب:  هناك 7 كواكب في المجموعة الشمسية (تشمل الأرض) و هناك بلايين الكواكب في الكون لكن لا نعرف عددها حالياً.',
#  'ما هي وسائل التكفيرعن الذنوب والمعاصي؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما هي وسائل التكفيرعن الذنوب والمعاصي؟\n    الإجابة: الوسائل التي تكفر بها الذنوب والمعاصي كثيرة منها: 1-الإستغفار. 2-الصدقة. 3-الصلاة. 4- الصيام. 5- الحج. 6- العمرة. 7- بر الوالدين. 8- صلة الأرحام. 9-حسن الجوار. 10-الجهاد في سبيل الله. 11-القراءة في كتب العلم. 12-ذكر الله. 13- الأمر بالمعروف والنهي عن المنكر. 14- الدعوة إلى الله. 15- الأمر بالمعروف والنهي عن المنكر. 16-الوصية الشرعية. 17-اللقطة بعد سنة. 18-مداركة الصلاة بعد خروج وقتها. 19- سجود السهو. 20- إفطار الصائم. 21- سجود التلاوة. 22- سجود الشكر. 23- الدعاء. 24- البكاء من خشية الله. 25- إسباغ الوضوء. 26- التبكير في الصلاة. 27- الخشوع في الصلاة. 28- إسباغ الوضوء. 29- إسباغ الوضوء. 30- إسباغ الوضوء.\n    """\n    كلمات مفتاحية: "الصدقة, الصيام, الحج, العمرة, بر الوالدين, صلة الأرحام, حسن الجوار, الجهاد في سبيل الله, القراءة في كتب العلم, ذكر الله, الأمر بالمعروف والنهي عن المنكر, الدعوة إلى الله, الأمر بالمعروف والنهي عن المنكر, الوصية الشرعية, اللقطة بعد سنة, مداركة الصلاة بعد خروج وقتها, سجود السهو, إفطار الصائم, سجود التلاوة, سجود الشكر, الدعاء, البكاء من خشية الله, إسباغ الوضوء, التبكير في الصلاة, الخشوع في الصلاة, إسباغ الوضوء, إسباغ الوضوء, إسباغ الوضوء"\n    # كلمات مفتاحية: "الصدقة, الصيام, الحج, العمرة, بر الوالدين, صلة الأرحام, حسن الجوار, الجهاد في سبيل الله, القراءة في كتب العلم, ذكر الله, الأمر بالمعروف والنهي عن المنكر, الدعوة إلى الله, الأمر بالمعروف والنهي عن المنكر, الوصية الشرعية, اللقطة بعد سنة, مداركة الصلاة بعد خروج وقتها, سجود السهو, إفطار الصائم, سجود التلاوة, سجود الشكر, الدعاء, البكاء من خشية الله, إسباغ الوضوء, التبكير في الصلاة, الخشوع في الصلاة, إسباغ الوضوء, إسباغ الوضوء, إسباغ الوضوء"\n    # كلمات مفتاحية: "الصدقة, الصيام, الحج, العمرة, بر الوالدين, صلة الأرحام, حسن الجوار, الجهاد في سبيل الله, القراءة في كتب العلم, ذكر الله, الأمر بالمعروف والنهي عن المنكر, الدعوة إلى الله, الأمر',
#  'ما الفلاح الحقيقي في الآخرة؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما الفلاح الحقيقي في الآخرة؟\n    الإجابة: الفوز بالجنة والنجاة من النار.\n    """\n    farm = []\n    for line in f:\n        words = line.split()\n        for word in words:\n            if word.strip():\n                farm.append(word)\n    return \'\\n\'.join(farm)\n\nif __name__ == \'__main__\':\n    print(get_farm(open(\'farm.txt\')))',
#  'في أي بلد يقع مقام سيدنا إبراهيم عليه السلام؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: في أي بلد يقع مقام سيدنا إبراهيم عليه السلام؟\n    الجواب: في المملكة العربية السعودية.',
#  'ما هي طرق تطهير القلب وتحليته بالصفات المحمودة؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما هي طرق تطهير القلب وتحليته بالصفات المحمودة؟\n    الإجابة: قال الله تعالى: ۱۸٢١ ۱۸٣١ ٢١ (سورة الأعراف, الآية ٩٥)\n    وقال الله تعالى: ۱۸١٢١ ۱۸١٢٢ ١٥ (سورة طه, الآية ١٥١)\n    وقال الله تعالى: ۱۸١٢٠ ۱۸١٢٢ ٢١ (سورة الشعراء, الآية ١٢٦)\n    وقال الله تعالى: ۱۸
�': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما عمر الأرض بالسنوات تحديدًا؟\n    الجواب: عمر الأرض يقدر بأربعة ونصف مليار سنة.\n    السؤال: ما عمر الشمس بالسنوات تحديدًا؟\n    الجواب: عمر الشمس يقدر بأربعة ونصف مليار سنة.\n    السؤال: ما عمر الكون بالسنوات تحديدًا؟\n    الجواب: عمر الكون يقدر بأربعة ونصف مليار سنة.\n    السؤال: ما عمر الإنسان بالسنوات تحديدًا؟\n    الجواب: عمر الإنسان يقدر بثمانين سنة.\n    السؤال: ما عمر النبي محمد بالسنوات تحديدًا؟\n    الجواب: عمر النبي محمد يقدر بـ 63 سنة.\n    السؤال: ما عمر القرآن بالسنوات تحديدًا؟\n    الجواب: عمر القرآن يقدر بـ 1ُ4٠٠ سنة.\n    السؤال: ما عمر الكعبة بالسنوات تحديدًا؟\n    الجواب: عمر الكعبة يقدر بـ 4٠٠٠ سنة.\n    السؤال: ما عمر برج إيفل بالسنوات تحديدًا؟\n    الجواب: عمر برج إيفل يقدر بـ 123 سنة.\n    السؤال: ما عمر الأهرامات بالسنوات تحديدًا؟\n    الجواب: عمر الأهرامات يقدر بـ 4500 سنة.\n    السؤال: ما عمر تاج محل بالسنوات تحديدًا؟\n    الجواب: عمر تاج محل يقدر بـ 300 سنة.\n    السؤال: ما عمر سور الصين العظيم بالسنوات تحديدًا؟\n    الجواب: عمر سور الصين العظيم يقدر بـ 2000 سنة.\n    السؤال: ما عمر برج خليفة بالسنوات تحديدًا؟\n    الجواب: عمر برج خليفة يقدر بـ 10٥ سنة.\n    السؤال: ما عمر سور الهند العظيم بالسنوات تحديدًا؟\n    الجواب: عمر سور الهند العظيم يقدر بـ 4٠٠٠ سنة.\n    السؤال: ما عمر سور روسيا العظيم بالسنوات تحديدًا؟\n    الجواب: عمر سور روسيا العظيم يقدر بـ 2000 سنة.\n    السؤال: ما عمر سور الصين العظيم بالسنوات تحديدًا؟\n    الجواب: عمر سور الصين العظيم يقدر بـ 2000 سنة.\n    السؤال: ما عمر برج خليفة بالسنوات تحديدًا؟\n    الجواب: عمر برج خليفة يقدر بـ 10٥ سنة.\n    السؤال: ما عمر سور الهند العظيم بالسنوات تحديدًا؟\n    الجواب: عمر سور الهند العظيم يقدر بـ 4٠٠٠ سنة.\n    السؤال: ما عمر سور روسيا العظيم بالسنوات تحديدًا؟\n    الجواب: عمر سور روسيا العظيم يقدر بـ 2000 سنة.\n    السؤال: ما عمر سور الصين العظيم بالسنوات تحديدًا؟\n    الجواب:',
#  'لماذا كان الرسول (صلى الله عليه وسلم) يُكثر من الاستغفار مع علمه بأن الله قد غفر له ما تقدم وما تأخر من ذنوبه؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: لماذا كان الرسول (صلى الله عليه وسلم) يُكثر من الاستغفار مع علمه بأن الله قد غفر له ما تقدم وما تأخر من ذنوبه؟\n    الإجابة: قال الله تعالى: {فاصبر إن وعد الله حق واستغفر لذنبك وسبح بحمد ربك بالعشي والإبكار} [غافر: 55]. وقال تعالى: {واستغفر لذنبك وللمؤمنين والمؤمنات} [محمد: 19]. وقال تعالى: {لقد تاب الله على النبي والمهاجرين والأنصار الذين اتبعوه في ساعة العسرة من بعد ما كاد يزيغ قلوب فريق منهم ثم تاب عليهم إنه بهم رؤوف رحيم * وعلى الثلاثة الذين خلفوا حتى إذا ضن الناس يعذبوا وظنوا أن لا ملجأ من الله إلا إليه ثم تاب عليهم ليتوبوا إن الله هو التواب الرحيم * يا أيها الذين آمنوا توبوا إلى الله توبة نصوحا عسى ربكم أن يكفر عنكم سيئاتكم ويدخلكم جنات تجري من تحتها الأنهار يوم لا يخزي الله النبي والذين آمنوا معه نورهم يسعى بين أيديهم وبأيمانهم يقولون ربنا أتمم لنا نورنا واغفر لنا إنك على كل شيء قدير} [التحريم: 67-68]. وقال تعالى: {وتوبوا إلى الله جميعا أيه المؤمنون لعلكم تفلحون} [النور: 31]. وقال تعالى: {إذا جاء نصر الله والفتح * ورأيت الناس يدخلون في دين الله أفواجا * فسبح بحمد ربك واستغفره إنه كان توأبا} [النصر: 1-3]. وقال تعالى: {لقد كان لكم في رسول الله أسوة حسنة لمن كان يرجو الله واليوم الآخر وذكر الله كثيرا * ولما رؤف بالمؤمنين ورهب غليهم ذكر الله} [الأحزاب: 21-22]. وقال تعالى: {إن الله وملائكته يصلون على النبي يا أيها الذين آمنوا صلوا عليه وسلموا تسليما} [الأحزاب: 56]. وقال تعالى: {إن الذين يؤذون الله ورسوله لعنهم الله في الدنيا والآخرة وأعد لهم عذابا مهينا} [الأحزاب: 57]. وقال تعالى: {ومن يطع الله ورسوله يدخله جنات تجري من تحتها الأنهار خالدين فيها وذلك الفوز العظيم * ومن يعص الله ورسوله ويتعد حدوده يدخله نارا خالدا فيها وله عذاب مهين} [النساء: 13-14]. وقال تعالى: {قل إن كان آباؤكم وأبنآؤكم وإخوانكم وأزواجكم وعشيرتكم وأموال اقترفتموها وتجارة تخشون كسادها ومساكن ترضونها أحب إليكم من الله ورسوله وجهاد في سبيله فتربصوا حتى يأتي الله بأمره والله لا يهدي القوم الفاسقين} [التوبة: 24]. وقال تعالى:',
#  'ما الأعمال التي تساعد في جلب الرزق؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما الأعمال التي تساعد في جلب الرزق؟\n    الإجابة: التجارة و الصناعة و الزراعة و الصيد.\n    """\n    import re\n    from collections import Counter\n\n    question = "أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة"\n    answer = "التجارة و الصناعة و الزراعة و الصيد."\n    pattern = r"([a-zA-Z\\s]+)"\n\n    words = re.findall(pattern, question)\n    counter = Counter(words)\n    ans_words = counter.most_common(1)\n\n    if len(ans_words) > 0:\n        ans = " ".join(ans_words[0][0])\n    else:\n        ans = "لا يوجد"\n\n    return ans\n\n\ndef get_name(question):\n    """\n    أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n    """\n    import re\n    from collections import Counter\n\n    question = "ما الأعمال التي تساعد في جلب الرزق؟"\n    answer = "التجارة و الصناعة و الزراعة و الصيد."\n    pattern = r"([a-zA-Z\\s]+)"\n\n    words = re.findall(pattern, question)\n    counter = Counter(words)\n    ans_words = counter.most_common(1)\n\n    if len(ans_words) > 0:\n        ans = " ".join(ans_words[0][0])\n    else:\n        ans = "لا يوجد"\n\n    return ans\n\n\ndef get_name_2(question):\n    """\n    أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n    """\n    import re\n    from collections import Counter\n\n    question = "ما الأعمال التي تساعد في جلب الرزق؟"\n    answer = "التجارة و الصناعة و الزراعة و الصيد."\n    pattern = r"([a-zA-Z\\s]+)"\n\n    words = re.findall(pattern, question)\n    counter = Counter(words)\n    ans_words = counter.most_common(1)\n\n    if len(ans_words) > 0:\n        ans = " ".join(ans_words[0][0])\n    else:\n        ans = "لا يوجد"\n\n    return ans\n\n\ndef get_name_3(question):\n    """\n    أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n    """\n    import re\n    from collections import Counter\n\n    question = "ما الأعمال التي تساعد في جلب الرزق؟"',
#  'متى تكون مجرما بحق نفسك؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: متى تكون مجرما بحق نفسك؟\n    ب- عندما لا تصلي.\n    ج- عندما تصلي ولكن لا تؤدي الزكاة.\n    د- عندما تصلي و تؤدي الزكاة و تصوم رمضان و تحج البيت.\n    الإجابة: ب- عندما لا تصلي.',
#  'ما الدليل على أن كون الإنسان مسلمًا لا يعني بالضرورة أنه بلغ مرتبة الإيمان؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما الدليل على أن كون الإنسان مسلمًا لا يعني بالضرورة أنه بلغ مرتبة الإيمان؟\n    ب- لأن الإيمان هو "ما وقر في القلب وصدقه العمل"، والمسلم قد يكون مصدقًا فقط ولا يكون عاملًا.\n    ج- لأن الإيمان هو "ما وقر في القلب وصدقه العمل"، والمسلم قد يكون عاملًا ولا يكون مصدقًا.\n    د- لأن الإيمان هو "ما وقر في القلب وصدقه العمل"، والمسلم قد يكون مصدقًا وعاملًا.\n    الجواب: د',
#  'ما حكم العلاقة الجنسية خارج إطار الزواج في الإسلام؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما حكم العلاقة الجنسية خارج إطار الزواج في الإسلام؟\n    الجواب: يحرم الإسلام الخلوة بين الجنسين و يأمر بغض البصر و يحفظ الأعراض، و لذلك يحرم ممارسة الجنس خارج إطار الزواج.',
#  'ما ضوابط وآداب الحرب في الإسلام؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما ضوابط وآداب الحرب في الإسلام؟\n    الجواب: 1. يحرم قتل النساء والصبيان والرهبان ونحوهم. 2. يحرم قطع الشجر المثمر والحرق. 3. يحرم التمثيل بالقتلى. 4. يحرم قتل من لا يجوز قتله كالحيوانات. 5. يحرم قتل المعاهد والمستأمن. 6. يحرم قتل النفس التي حرم الله إلا بالحق. 7. يحرم ترويع الآمنين. 8. يحرم البغى على الحاكم. 9. يحرم الإسراف في المال. 10. يحرم التجسس. 11. يحرم الخيانة. 12. يحرم التخذيل. 13. يحرم المن. 14. يحرم خذلان المسلمين. 15. يحرم موالاة أعداء الله. 16. يحرم الفرار من الزحف. 17. يحرم البغى. 18. يحرم البغي. 19. يحرم البغي. 20. يحرم البغي.',
#  'ما الغاية من الصيام؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما الغاية من الصيام؟\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي حالة الفقراء وتحسوا بهم )\n    الإجابة:  لكي تُقَدِّرُوا الْفَقْرَ  ( لكي تعلموا ما هي',
#  'ما هو موقف الإسلام من الموت الرحيم (الموت بمساعدة طبية)؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما
�': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما الفلاح الحقيقي في الدنيا؟\n    الإجابة: الفلاح الحقيقي في الدنيا هو أن تعمل عملاً نافعاً في الدنيا والآخرة.\n    السؤال: ما هو العمل الذي ينفع في الدنيا والآخرة؟\n    الإجابة: العمل الذي ينفع في الدنيا والآخرة هو العمل الصالح.\n    السؤال: ما هو العمل الصالح؟\n    الإجابة: العمل الصالح هو كل عمل أمر الله به أو أمر به رسوله - صلى الله عليه وسلم -، بشرط أن يكون هذا العمل موافقًا للشرع.\n    السؤال: ما هو الشرع؟\n    الإجابة: الشرع هو ما شرعه الله على لسان رسوله - صلى الله عليه وسلم - من أحكام.\n    السؤال: ما هو الدليل على أن العمل الذي أمر الله به أو أمر به رسوله - صلى الله عليه وسلم -، بشرط أن يكون هذا العمل موافقًا للشرع، هو العمل الصالح؟\n    الإجابة: قال الله تعالى: (من عمل صالحا من ذكر أو أنثى وهو مؤمن فلنحيينه حياة طيبة ولنجزينهم أجرهم بأحسن ما كانوا يعملون) [النحل: 97]. وقال الله تعالى: (إن الذين آمنوا وعملوا الصالحات أولئك هم خير البرية) [البينة: 7]. وقال الله تعالى: (فمن كان يرجو لقاء ربه فليعمل عملا صالحا ولا يشرك بعبادة ربه أحدا) [الكهف: 110]. وقال الله تعالى: (إن الذين هم من خشية ربهم مشفقون (57) والذين هم محسنون (58) أولئك لهم عقبى الدار (59) ولقد اصطفينا بني إسرائيل وءاتيناهم كتبًا فصلناه على علم وهدى ورحمة) [الدار: 57-59]. وقال الله تعالى: (إن الذين قالوا ربنا الله ثم استقاموا فلا خوف عليهم ولا هم يحزنون (13) أولئك أصحاب الجنة خالدين فيها جزاء بما كانوا يعملون) [الأحقاف: 13-14]. وقال الله تعالى: (فمن تاب من بعد ظلمه وأصلح فإن الله يتوب عليه إن الله غفور رحيم) [المائدة: 39]. وقال الله تعالى: (إلا الذين تابوا وأصلحوا واعتصموا بالله وأخلصوا دينهم لله) [النساء: 146]. وقال الله تعالى: (إلا الذين تابوا من بعد ذلك وأصلحوا فإن الله غفور رحيم) [النور: 5]. وقال الله تعالى: (إلا الذين تابوا وأصلحوا واعتصموا بالله وأخلصوا دينهم لله) [الأحقاف: من الآية11]. وقال الله تعالى: (إلا الذين تابوا وأصلحوا واعتصموا بالله هو مولاكم) [الملك: من الآية16]. وقال الله تعالى: (',
#  'هل الإسلام والإيمان مفهوم واحد؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: هل الإسلام والإيمان مفهوم واحد؟\n    الجواب: لا، الإسلام والإيمان ليسا نفس الشيء. الإسلام هو فعل الخضوع والاستسلام لله، في حين أن الإيمان هو الاعتقاد في الله وملائكته وكتبه ورسله.\n    """\n    question = "هل الإسلام والإيمان مفهوم واحد؟"\n    answer = "لا، الإسلام والإيمان ليسا نفس الشيء. الإسلام هو فعل الخضوع والاستسلام لله، في حين أن الإيمان هو الاعتقاد في الله وملائكته وكتبه ورسله."\n    return_data = {}\n    return_data[\'question\'] = question\n    return_data[\'answer\'] = answer\n    return return_data\n\n\ndef get_data_2():\n    """\n    أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما هو اسم زوجة النبي يوسف؟\n    الجواب: زليخة.\n    """\n    question = "ما هو اسم زوجة النبي يوسف؟"\n    answer = "زليخة."\n    return_data = {}\n    return_data[\'question\'] = question\n    return_data[\'answer\'] = answer\n    return return_data\n\n\ndef get_data_3():\n    """\n    أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما
([isinstance(x, str) for x in question]):\n            for i, line in enumerate(question):\n                if isinstance(line, str):\n                    question[i] = _get_yes_no_numerical(line)\n        else:\n            question = _get_yes_no_numerical(question)\n    elif isinstance(question, list):\n        question = _get_yes_no_numerical(question)\n    else:\n        raise TypeError("Invalid type for question")\n\n    if isinstance(answer, str):\n        answer = answer.split("\\n")\n        if any([isinstance(x, str) for x in answer]):\n            for i, line in enumerate(answer):\n                if isinstance(line, str):\n                    answer[i] = _get_yes_no_numerical(line)\n        else:\n            answer = _get_yes_no_numerical(answer)\n    elif isinstance(answer, list):\n        answer = _get_yes_no_numerical(answer)\n    else:\n        raise TypeError("Invalid type for answer")\n\n    if (len(question)!= len(answer)):\n        raise ValueError("Length of question and answer must be equal")\n\n    return np.array(question).mean() == np.array(answer).mean()',
#  'كيف يمكن التعريف بشخصية الرسول صلى الله عليه وسلم وصفاته الحميدة؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: كيف يمكن التعريف بشخصية الرسول صلى الله عليه وسلم وصفاته الحميدة؟\n    الجواب:\n    - من خلال ذكر القرآن الكريم وأحاديث السنة النبوية له.\n    - من خلال ذكر سيرته العطرة.\n    - من خلال ذكر أخلاقه العالية.\n    - من خلال ذكر معجزاته الدالة على نبوته.\n    - من خلال ذكر فضائله الكثيرة.',
#  'ما الحكم الشرعي للإجهاض بعد نفخ الروح في الجنين؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما الحكم الشرعي للإجهاض بعد نفخ الروح في الجنين؟\n    الجواب: الإجهاض بعد نفخ الروح في الجنين جريمة كبيرة وجناية عظيمة، يحرم ارتكابه على من أقدم عليه، رجلا كان أو امرأة، وهو يعتبر قتل نفس بغير حق، يحرم على كل أحد أن يقترف هذه الجريمة، أو يشارك فيها بقول أو بفعل، أو إعانة على ذلك بأي وسيلة كانت، سواء كان الجنين نفخت فيه الروح أو لم تنفخ فيه بعد، وسواء كان الإجهاض في بداية الحمل أو في أواخره، على قول من يقول إن نفخ الروح لا يكون إلا بعد 120 يوما، وعلى قول من يقول إن نفخ الروح يكون بعد 80 يوما، وعلى قول من يقول إن نفخ الروح يكون بعد 40 يوما، على اختلاف بين أهل العلم في هذه المسألة.',
#  'ماذا تعني العبودية لغير الله؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ماذا تعني العبودية لغير الله؟\n    الجواب: العبودية لغير الله تعني صرف شيء من العبادة التي لا تصرف إلا لله لأحد غيره.\n    السؤال: ما هي العبادة التي لا تصرف إلا لله؟\n    الجواب: العبادة التي لا تصرف إلا لله هي الألوهية.\n    السؤال: ما معنى الألوهية؟\n    الجواب: الألوهية هي العبودية، وهي خالص العبادة، ومستحقها.\n    السؤال: ما هي أنواع العبودية؟\n    الجواب: أنواع العبودية هي: العبودية العامة، والعبودية الخاصة.\n    السؤال: ما هي العبودية العامة؟\n    الجواب: العبودية العامة هي عبودية جميع المخلوقات، وهي عبودية اضطرار لا عبودية اختيار.\n    السؤال: ما هي العبودية الخاصة؟\n    الجواب: العبودية الخاصة هي عبودية خواص المخلوقات، وهي عبودية اختيار.\n    السؤال: ما هي أدلة إثبات العبودية الخاصة؟\n    الجواب: أدلة إثبات العبودية
ين.\n    السؤال: ما هي أقل آية فيها حروف في القرآن الكريم؟\n    الجواب: كلمة (هو) في سورة الحديد.\n    السؤال: ما هي أكثر كلمة فيها حروف في القرآن الكريم؟\n    الجواب: كلمة (إياك) في سورة الكهف.\n    السؤال: ما هي أقل كلمة فيها حروف في القرآن الكريم؟\n    الجواب: كلمة (هو) في سورة الحديد.\n    السؤال: ما هي أكثر آية فيها حروف مقطعة في القرآن الكريم؟\n    الجواب: آية الدين.\n    السؤال: ما هي أقل آية فيها حروف مقطعة في القرآن الكريم؟\n    الجواب: كلمة (هو) في سورة الحديد.\n    السؤال: ما هي أكثر كلمة فيها حروف مقطعة في القرآن الكريم؟\n    الجواب: كلمة (إياك) في سورة الكهف.\n    السؤال: ما هي أقل كلمة',
#  ' ما الحكمة في إخفاء ليلة القدر في العشر الأواخر من رمضان وعدم التصريح بها بشكل قاطع؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال:  ما الحكمة في إخفاء ليلة القدر في العشر الأواخر من رمضان وعدم التصريح بها بشكل قاطع؟\n    الجواب:  حتى يتفرغ الإنسان في هذا الشهر للعبادة والطاعة، ولا ينشغل بالترقب والانتظار، فيفوته من الخير الكثير.',
#  'ما هو حكم زواج المرأة المسلمة من رجل مسيحي؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما هو حكم زواج المرأة المسلمة من رجل مسيحي؟\n    الجواب: يحرم زواج المرأة المسلمة من الرجل المسيحي.\n    """\n    _ الزواج_بالكتابيات = (\n       \'يحرم زواج المرأة المسلمة من الرجل \')\n\n    @staticmethod\n    def answer(السؤال):\n        """إجابة السؤال المعطى باستخدام مصطلحات من القرآن و السنة\n        :param السؤال: السؤال\n        :return: الإجابة\n        """\n        # تقسيم السؤال إلى كلمات منفصلة\n        كلمات = question.split ()\n        # تحقق مما إذا كان السؤال هو سؤال حقيقي\n        إذا كان السؤال ليس في _ الزواج_بالكتابيات:\n            عودة "لا"\n        # تحقق مما إذا كان السؤال يحتوي على أي كلمات أخرى غير "زواج" أو "امرأة" أو "رجل" أو "مسيحي"\n        كلمات أخرى = []\n        لأنا في النطاق (0, عدد (كلمات)):\n            إذا كانت الكلمات [I] ليست في مجموعة (["زواج", "امرأة", "رجل", "مسيحي"]):\n                كلمات أخرى. التذييل (كلمات [I])\n        إذا كان عدد (كلمات أخرى) > 0:\n            عودة "لا إجابة"\n        # تحقق مما إذا كان السؤال هو السؤال الصحيح\n        إذا كان السؤال في _ الزواج_بالكتابيات:\n            عودة "نعم"\n        آخر:\n            عودة "لا إجابة"',
#  'هل يُعتبر الحوار مع أتباع الديانات الأخرى واجبًا على المسلم في سياق الدعوة إلى الإسلام؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: هل يُعتبر الحوار مع أتباع الديانات الأخرى واجبًا على المسلم في سياق الدعوة إلى الإسلام؟\n   ...\n\n    الإجابة: نعم، يعتبر الحوار مع أتباع الديانات الأخرى واجبًا على المسلم في سياق الدعوة إلى الإسلام، لأن الدعوة إلى الله هي وظيفة الأمة الإسلامية، قال الله تعالى: {ولتكن منكم أمة يدعون إلى الخير ويأمرون بالمعروف وينهون عن المنكر} [آل عمران:104], وقال تعالى: {ومن أحسن قولًا مِن دعا إلى الله وعملَ صُلًحًا وقال إنني من المسلمين} [سورة: فصلت:33].\n   ...\n\n    السؤال: ما هي أهمية الحوار مع أتباع الديانات الأخرى؟\n   ...\n\n    الإجابة: الحوار مع أتباع الديانات الأخرى له أهمية كبيرة، منها:\n    1- الدعوة إلى الإسلام.\n    2- التعرف على الآخرين.\n    3- تصحيح المفاهيم الخاطئة.\n    4- التعاون على البر والتقوى.\n    5- تحقيق التعايش السلمي بين الأمم.\n   ...',
#  'ما هو الإتقان؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: ما هو الإتقان؟\n    الجواب: الإتقان هو أن تقوم بالعمل بأفضل طريقة ممكنة.\n    """\n    def _get_answer(question):\n        answer = ""\n        for term in question.split():\n            if term in TERMS:\n                answer += " " + TERMS[term]\n        return answer\n\n    return _get_answer\n\n@app.route(\'/\')\ndef index():\n    questions = [\n        "من هو الله؟",\n        "ما هي أسماء الله؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء يوم القيامة؟",\n        "ما هي أسماء',
#  ' ما العوامل التي تُحبط العمل الصالح وتحول دون قبوله في الآخرة؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال:  ما العوامل التي تُحبط العمل الصالح وتحول دون قبوله في الآخرة؟\n    الجواب: الشرك بالله، وقتل النفس التي حرم الله قتلها، وأكل مال اليتيم، والتولي يوم الزحف، وقذف المحصنات المؤمنات الغافلات، وشهادة الزور.',
#  'كم مرة يُعاقب المنافق في الدنيا؟': 'أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة\n   ...\n\n    السؤال: كم مرة يُعاقب المنافق في الدنيا؟\n    الإجابة: يُعاقب في الدنيا سبع مرات.\n    الشرح: قال الله تعالى: (إن الذين يرمون المحصنات الغافلات المؤمنات لعنوا في الدنيا والآخرة ولهم عذاب عظيم) [النور: 23]. وقال تعالى: (إن الذين يؤذون الله ورسوله لعنهم الله في الدنيا والآخرة) [الأحزاب: 57]. وقال تعالى: (إن الذين يرمون أزواجهم ولم يكن لهم شهداء إلا أنفسهم فشهادة أحدهم أربع شهادات بالله إنه لمن الصادقين) [النور: 6]. وقال تعالى: (إن الذين يرمون المحصنات ثم لم يأتوا بأربعة شهداء فاجلدوهم ثمانين جلدة ولا تقبلوا لهم شهادة أبدا وأولئك هم الفاسقون) [النور: 4]. وقال تعالى: (إن الذين يحبون أن تشيع الفاحشة في الذين آمنوا لهم عذاب أليم في الدنيا والآخرة والله يعلم وأنتم لا تعلمون) [النور: 19]. وقال تعالى: (يوم تشهد عليهم ألسنتهم وأيديهم وأرجلهم بما كانوا يعملون) [النور: 24]. وقال تعالى: (يومئذ يوفيهم الله دينهم الحق ويعلمون أن الله هو الحق المبين) [النور: 25]. وقال تعالى: (ليجزيهم الله أحسن ما عملت ويزيدهم من فضلة والله يرزق من يشاء والله ذو القوة المتين) [النور: 38]. وقال تعالى: (يوم لا يخزي الله النبي والذين آمنوا معه نورهم يسعى بين أيديهم وبأيمانهم يقولون ربنا أتمم لنا نورنا واغفر لنا إنك على كل شيء قدير) [التحريم: 8]. وقال تعالى: (يوم لا ينفع مال ولا بنون إلا من أتى الله بقلب سليم) [الشعراء: 88- 89]. وقال تعالى: (يوم لا تملك نفس لنفس شيئا والأم
n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n    ذُكر: {وما كان صلاتهم عند البيت إلا مكاء وتصدية فذوقوا العذاب بما كنتم تكفرون} [الأنفال: 35]\n   '}

# %%
llm_responces_test = get_llm_responces(unique_arabic_questions_test)
# Out:
# Processing 53 unique Arabic questions...
# Processed 10/53 questions.
# Processed 20/53 questions.
# Processed 30/53 questions.
# Processed 40/53 questions.
# Processed 50/53 questions.
#
# Successfully received responses for 53/53 questions.
# Failed to receive responses for 0/53 questions.
#
# Sample LLM Response:
# Question: nan
# Response:
# أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة
#    ...
#
#     السؤال: nanette, 5,000,000
#     الإجابة: "إن الله على كل شيء قدير".

# %%
llm_responces_dev = get_llm_responces(unique_arabic_questions_dev)
# Out:
# Processing 40 unique Arabic questions...
# Processed 10/40 questions.
# Processed 20/40 questions.
# Processed 30/40 questions.
# Processed 40/40 questions.
#
# Successfully received responses for 40/40 questions.
# Failed to receive responses for 0/40 questions.
#
# Sample LLM Response:
# Question: من الذي خسف الله به الأرض؟
# Response:
# أعطني إجابة من القرآن و السنة فقط إن وجدت و اجعل الرد جمل كاملة باقل عدد من الكلمات و قم باستخدام مصطلحات من القرآن و السنة و في حالة عدم وجود اجابة في القرآن و السنة قل لا يوجد اجابة
#    ...
#
#     السؤال: من الذي خسف الله به الأرض؟
#     الجواب: قارون.

# %%
llm_responses_1 = llm_responses.copy()

# %%
llm_responses_2 = llm_responses.copy()

# %%
pd.merge(ayatec_dev,pd.Series({q : a.split("السؤال:")[1].split("\n")[1].strip().replace("الجواب:","") for q,a in llm_responces_dev.items()},name="arabic_augment"), left_on="arabic",right_index=True, how="left").\
to_csv("../Data/augmented_preprocessed_questions_with_answers_dev.csv",index=False)

# %%
pd.merge(ayatec,pd.Series({q : a.split("السؤال:")[1].split("\n")[1].strip().replace("الجواب:","") for q,a in llm_responses_2.items()},name="arabic_augment"), left_on="arabic",right_index=True, how="left").\
to_csv("../Data/augmented_preprocessed_questions_with_answers_train.csv",index=False)

# %%
pd.Series({q : a.split("السؤال:")[1].split("\n")[1].strip() for q,a in llm_responses_2.items()})
# Out:
# من هم قوم شعيب؟                                                                    الجواب:  أهل مدين.
# من هم قوم موسى؟                                                      الجواب: قوم موسى هم بنو إسرائيل.
# من بنى الكعبة؟                                             الجواب: الملائكة وآدم و إبراهيم و إسماعيل.
# من هو النبي المعروف بالصبر؟                                           الجواب: النبي أيوب عليه السلام.
# من كفل السيدة مريم؟                                                        الجواب: كفلها النبي زكريا.
#                                                                           ...
# ما هي أكثر صفقات البيع ربحا التي ذكرها القرآن؟      الجواب:  "إن الله اشترى من المؤمنين أنفسهم وأم...
# هل يستطيع الشيطان أن يغوي جميع الناس؟               الجواب: نعم ، يستطيع الشيطان أن يغوي جميع النا...
# من هم العشرة المبشرين بالجنة؟                       الجواب: هم عشرة من الصحابة بشرهم النبي صلى الل...
# هل يعتبر الإسلام ديناً متعدد الثقافات والعرقيات؟                                         الجواب: نعم.
# هل هناك دليل أو أدلة على وحدة الأديان ...؟          الجواب: قال الله تعالى: (إن هذه أمتكم أمة واحد...
# Length: 210, dtype: object

# %%
list(llm_responses.keys())[7]
# Out:
# 'ما معنى القارعة؟'

# %%
print(list(llm_responses_2.values())[2].split("السؤال:")[1])
# Out:
#  من بنى الكعبة؟
#     الجواب: الملائكة وآدم و إبراهيم و إسماعيل.

# %%
print(llm_responses['لماذا جعل الله معجزة سيدنا صالح الناقة؟'])
# Out:
# أعطني إجابة باقل عدد كلمات باستخدام مصطلحات من القرآن و السنة
#    ...
#
#     السؤال: لماذا جعل الله معجزة سيدنا صالح الناقة؟
#     الجواب:  لأن قوم ثمود كانوا ينحتون الجبال، و يتخذونها بيوتًا.
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و هم: (دان، نفتالي، جاد، آشر).
#     السؤال: ما هي أسماء إخوة يوسف في القرآن؟
#     الجواب:  في القرآن لم يُذكر أسماء إخوة يوسف، لكن في العهد القديم (التوراة) مذكورون بالإسم و

# %% [markdown]
# ## Call llm
#
# ### Subtask:
# Retry calling the LLM to get possible answers and vocabulary synonyms for each Arabic question, addressing the previous API key configuration failure.

# %% [markdown]
# **Reasoning**:
# Retry calling the LLM to get possible answers and vocabulary synonyms for each Arabic question, addressing the previous API key configuration failure by ensuring correct setup and error handling.

# %%
import google.generativeai as genai
import os
from google.colab import userdata

# Configure the API key
try:
    genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))
    print("Google API key configured successfully.")
except Exception as e:
    print(f"Failed to configure Google API key. Please ensure the 'GOOGLE_API_KEY' secret is set in Colab user data: {e}")
    # Finish the task with failure if API key configuration fails
    raise  # Re-raise the exception to indicate failure


# Initialize the LLM model
# Choose an appropriate model, e.g., 'gemini-1.5-flash' or 'gemini-1.5-pro'
# Ensure the model name is correct and accessible
model_name = 'gemini-1.5-flash' # Using gemini-1.5-flash as it's cost-effective and suitable
try:
    model = genai.GenerativeModel(model_name)
    print(f"LLM model '{model_name}' initialized successfully.")
except Exception as e:
    print(f"Failed to initialize LLM model '{model_name}': {e}")
    # Finish the task with failure if model initialization fails
    raise # Re-raise the exception to indicate failure

# Dictionary to store LLM responses
llm_responses = {}

# Iterate through unique Arabic questions and get LLM responses
print(f"Processing {len(unique_arabic_questions)} unique Arabic questions...")
for i, question in enumerate(unique_arabic_questions):
    prompt = create_llm_prompt(question)
    try:
        # Call the LLM
        response = model.generate_content(prompt)
        # Store the text response
        llm_responses[question] = response.text
        if (i + 1) % 10 == 0:
            print(f"Processed {i + 1}/{len(unique_arabic_questions)} questions.")
    except Exception as e:
        print(f"Error processing question '{question}': {e}")
        # Store an informative error message for failed requests
        llm_responses[question] = f"Error: {e}"

# Print summary
successful_responses = sum(1 for resp in llm_responses.values() if not str(resp).startswith("Error:"))
print(f"\nSuccessfully received responses for {successful_responses}/{len(unique_arabic_questions)} questions.")
failed_responses = len(unique_arabic_questions) - successful_responses
print(f"Failed to receive responses for {failed_responses}/{len(unique_arabic_questions)} questions.")


# Display a sample successful response
if successful_responses > 0:
    print("\nSample LLM Response:")
    # Find the first question with a successful response
    sample_question = None
    for q, resp in llm_responses.items():
        if not str(resp).startswith("Error:"):
            sample_question = q
            break
    if sample_question:
        print(f"Question: {sample_question}")
        print("Response:")
        print(llm_responses[sample_question])
    else:
        print("No successful responses found to display.")
else:
    print("No successful responses received.")
# Out:
# Failed to load model 'core42/jais-13b-chat': name 'AutoTokenizer' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 model_name = "core42/jais-13b-chat" # Example model name, please verify the correct one
#       4 try:
# ----> 5     tokenizer = AutoTokenizer.from_pretrained(model_name)
#       6     model = AutoModelForCausalLM.from_pretrained(
#       7         model_name,
#       8         torch_dtype=torch.bfloat16, # Use bfloat16 for potentially lower memory usage
#    (...)
#      12         # bnb_4bit_compute_dtype=torch.bfloat16,
#      13     )
#      14     # Move model to MPS if available
#
# NameError: name 'AutoTokenizer' is not defined

# %% [markdown]
# ## Process llm responses
#
# ### Subtask:
# Parse the LLM's responses to extract the generated possible answers and synonyms.

# %% [markdown]
# **Reasoning**:
# Iterate through the LLM responses and parse the possible answers and synonyms based on the expected format.

# %%
parsed_llm_data = {}

for question, response_text in llm_responses.items():
    if isinstance(response_text, str) and not response_text.startswith("Error:"):
        possible_answers = []
        synonyms = {}

        # Split the response into sections based on the headings
        sections = response_text.split('المرادفات:')
        answer_section = sections[0].replace('الإجابات المحتملة:', '').strip()

        # Parse Possible Answers
        if answer_section:
            # Split by bullet points and clean up each item
            answers_list = [item.strip() for item in answer_section.split('-') if item.strip()]
            possible_answers = answers_list

        # Parse Synonyms
        if len(sections) > 1:
            synonym_section = sections[1].strip()
            if synonym_section:
                # Split by bullet points for each key term
                synonym_lines = [line.strip() for line in synonym_section.split('-') if line.strip()]
                for line in synonym_lines:
                    if ':' in line:
                        term, syn_list_str = line.split(':', 1)
                        term = term.strip()
                        # Split synonyms by comma and clean up
                        syn_list = [s.strip() for s in syn_list_str.split(',') if s.strip()]
                        if term:
                            synonyms[term] = syn_list

        parsed_llm_data[question] = {
            'possible_answers': possible_answers,
            'synonyms': synonyms
        }
    else:
        # Handle error responses or unexpected formats
        parsed_llm_data[question] = {
            'possible_answers': [],
            'synonyms': {},
            'error': response_text if isinstance(response_text, str) else "Unexpected response format"
        }

# Display a sample of the parsed data
sample_question = list(parsed_llm_data.keys())[0]
print("Sample Parsed LLM Data:")
print(f"Question: {sample_question}")
print(parsed_llm_data[sample_question])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-54-2775678847.py in <cell line: 0>()
#       1 parsed_llm_data = {}
#       2
# ----> 3 for question, response_text in llm_responses.items():
#       4     if isinstance(response_text, str) and not response_text.startswith("Error:"):
#       5         possible_answers = []
#
# NameError: name 'llm_responses' is not defined

# %% [markdown]
# ## Integrate with data
#
# ### Subtask:
# Integrate the extracted information (possible answers, synonyms) into the main dataset or a new structure, associating them with the original Arabic questions.

# %% [markdown]
# **Reasoning**:
# Convert the parsed LLM data into a pandas DataFrame and merge it with the ayatec DataFrame based on the Arabic question. Then display the head of the merged DataFrame to verify the integration.

# %%
import pandas as pd

# Convert parsed_llm_data to DataFrame
# We need to handle the structure of the data, especially the synonyms dictionary.
# For simplicity, convert the synonyms dictionary to a string representation.
llm_df = pd.DataFrame.from_dict(parsed_llm_data, orient='index')
llm_df.index.name = 'arabic' # Rename index to match the merge column
llm_df['synonyms_str'] = llm_df['synonyms'].apply(lambda x: json.dumps(x) if isinstance(x, dict) else None)

# Merge with the original ayatec DataFrame
# Use a left merge to keep all rows from ayatec
ayatec_enriched = ayatec.merge(llm_df[['possible_answers', 'synonyms_str']],
                               left_on='arabic',
                               right_index=True,
                               how='left')

# Display the head of the merged DataFrame
display(ayatec_enriched.head())

# Display columns to confirm new columns are added
print(ayatec_enriched.columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-55-3994496004.py in <cell line: 0>()
#       6 llm_df = pd.DataFrame.from_dict(parsed_llm_data, orient='index')
#       7 llm_df.index.name = 'arabic' # Rename index to match the merge column
# ----> 8 llm_df['synonyms_str'] = llm_df['synonyms'].apply(lambda x: json.dumps(x) if isinstance(x, dict) else None)
#       9
#      10 # Merge with the original ayatec DataFrame
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     415                 raise KeyError(key) from err
#     416         if isinstance(key, Hashable):
# --> 417             raise KeyError(key)
#     418         self._check_indexing_error(key)
#     419         raise KeyError(key)
#
# KeyError: 'synonyms'

# %% [markdown]
# **Reasoning**:
# The previous command failed because the 'synonyms' column was not found in the DataFrame created from `parsed_llm_data`. This indicates that `parsed_llm_data` does not have the expected structure, likely due to the previous LLM call failures. I need to inspect the structure of `parsed_llm_data` to understand its content before attempting to convert it to a DataFrame and merge.

# %%
print(parsed_llm_data)
# Out:
# {}

# %% [markdown]
# ## Evaluate impact
#
# ### Subtask:
# Analyze the impact of using the enriched data (possible answers, synonyms) on the retrieval pipeline's performance.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 210 unique Arabic questions.
# *   Attempts to configure the Google Generative AI library and initialize the LLM failed due to a `SecretNotFoundError`, indicating the `GOOGLE_API_KEY` was not found in the Colab user data.
# *   Consequently, the LLM could not be called to generate possible answers and synonyms for the Arabic questions.
# *   Due to the failure in calling the LLM, the `llm_responses` and `parsed_llm_data` variables were not populated, leading to subsequent failures in parsing and integrating the non-existent data.
# *   The final step of evaluating the impact of the enriched data on the retrieval pipeline could not be performed as the enriched data was not successfully generated.
#
# ### Insights or Next Steps
#
# *   The primary next step is to ensure the `GOOGLE_API_KEY` secret is correctly configured in the Colab user data to allow the LLM calls to proceed.
# *   After successfully obtaining LLM responses, the parsing and integration steps need to be executed to prepare the enriched data for evaluation.

# %%
# Install necessary libraries
# !pip install transformers accelerate bitsandbytes

# %%
# Out:
# tokenizer_config.json:   0%|          | 0.00/247 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/131 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# configuration_jais.py:   0%|          | 0.00/6.76k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/core42/jais-13b-chat:
# - configuration_jais.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_jais.py:   0%|          | 0.00/68.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/core42/jais-13b-chat:
# - modeling_jais.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin.index.json:   0%|          | 0.00/42.3k [00:00<?, ?B/s]
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# pytorch_model-00002-of-00006.bin:   0%|          | 0.00/9.79G [00:00<?, ?B/s]
# pytorch_model-00004-of-00006.bin:   0%|          | 0.00/9.75G [00:00<?, ?B/s]
# pytorch_model-00006-of-00006.bin:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# pytorch_model-00003-of-00006.bin:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# pytorch_model-00005-of-00006.bin:   0%|          | 0.00/9.79G [00:00<?, ?B/s]
# pytorch_model-00001-of-00006.bin:   0%|          | 0.00/9.99G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
